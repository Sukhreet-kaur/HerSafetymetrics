# %% [markdown]
# # **Two Decades of Women Safety in India (2001–2021)**
# ### An Exploratory Data Analysis of Crime Trends

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Importing the essential libraries for our project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Reading our CSV data to analyse**

# %%
url = 'https://drive.google.com/uc?export=download&id=1j8tOcMfhRZPL1ijwYX3AMc6iuy_Udnve'
df = pd.read_csv(url)
df
# Out:
#       year           state             district  rape  attempt_to_rape  \
# 0     2001  Andhra Pradesh    Andhra District 1     3                7
# 1     2001  Andhra Pradesh    Andhra District 2     3                4
# 2     2001  Andhra Pradesh    Andhra District 3     3                6
# 3     2001  Andhra Pradesh    Andhra District 4     2                8
# 4     2001  Andhra Pradesh    Andhra District 5     2                7
# ...    ...             ...                  ...   ...              ...
# 9995  2020         Mizoram  Mizoram District 10    21               14
# 9996  2020         Mizoram  Mizoram District 11    23               14
# 9997  2020         Mizoram  Mizoram District 12    28               33
# 9998  2020         Mizoram  Mizoram District 13    18               14
# 9999  2020        Nagaland  Nagaland District 1    33               33
#
#       gang_rape  murder_with_rape  kidnapping_and_abduction  dowry_deaths  \
# 0             3                 5                        11             4
# 1             5                 6                         9             4
# 2             4                 7                        13             5
# 3             4                 7                        20             1
# 4             4                 9                        15             4
# ...         ...               ...                       ...           ...
# 9995          9                22                        43            20
# 9996         12                17                        32            24
# 9997         21                16                        29            18
# 9998         15                15                        29            17
# 9999         33                36                        48            33
#
#       dowry_prohibition_act  ...  abduction_for_illicit_intercourse  \
# 0                        12  ...                                  8
# 1                         5  ...                                  4
# 2                         5  ...                                  2
# 3                         4  ...                                  5
# 4                         7  ...                                  9
# ...                     ...  ...                                ...
# 9995                     20  ...                                 28
# 9996                     25  ...                                 19
# 9997                     19  ...                                 21
# 9998                     22  ...                                 23
# 9999                     30  ...                                 33
#
#       attempt_to_kidnap  domestic_violence_act_cases  \
# 0                     8                           10
# 1                     4                            6
# 2                     6                            5
# 3                     5                            6
# 4                     6                            0
# ...                 ...                          ...
# 9995                 13                           11
# 9996                 14                           22
# 9997                 13                           11
# 9998                 19                           18
# 9999                 30                           29
#
#       abetment_to_suicide_women  attempt_to_murder_women  \
# 0                             4                        4
# 1                             7                        3
# 2                             6                        6
# 3                             7                        6
# 4                             4                        3
# ...                         ...                      ...
# 9995                         14                       24
# 9996                         14                       16
# 9997                         20                       15
# 9998                         23                       15
# 9999                         31                       41
#
#       insult_outraging_modesty_other  sexual_harassment_workplace  \
# 0                                  5                            5
# 1                                  2                            4
# 2                                  3                            3
# 3                                  7                            3
# 4                                  6                            8
# ...                              ...                          ...
# 9995                              19                           16
# 9996                              23                           15
# 9997                              14                           14
# 9998                              30                           15
# 9999                              41                           25
#
#       dowry_harassment  marital_rape_reports  total_cases
# 0                    2                     3          512
# 1                    7                     6          497
# 2                    5                     2          511
# 3                    2                     3          476
# 4                    0                     3          506
# ...                ...                   ...          ...
# 9995                19                    16         1731
# 9996                17                    19         1676
# 9997                26                    18         1754
# 9998                20                    15         1756
# 9999                32                    42         3136
#
# [10000 rows x 44 columns]

# %% [markdown]
# ## Read first 5 rows of the data

# %%
df.head(30)
# Out:
#     year              state               district  rape  attempt_to_rape  \
# 0   2001     Andhra Pradesh      Andhra District 1     3                7
# 1   2001     Andhra Pradesh      Andhra District 2     3                4
# 2   2001     Andhra Pradesh      Andhra District 3     3                6
# 3   2001     Andhra Pradesh      Andhra District 4     2                8
# 4   2001     Andhra Pradesh      Andhra District 5     2                7
# 5   2001     Andhra Pradesh      Andhra District 6     7                3
# 6   2001     Andhra Pradesh      Andhra District 7     8                5
# 7   2001     Andhra Pradesh      Andhra District 8     6                5
# 8   2001     Andhra Pradesh      Andhra District 9     4                4
# 9   2001     Andhra Pradesh     Andhra District 10     8                5
# 10  2001     Andhra Pradesh     Andhra District 11     4                6
# 11  2001     Andhra Pradesh     Andhra District 12     2                5
# 12  2001     Andhra Pradesh     Andhra District 13     5                7
# 13  2001     Andhra Pradesh     Andhra District 14     6                4
# 14  2001  Arunachal Pradesh   Arunachal District 1    15               23
# 15  2001  Arunachal Pradesh   Arunachal District 2    18               14
# 16  2001  Arunachal Pradesh   Arunachal District 3    24               23
# 17  2001  Arunachal Pradesh   Arunachal District 4    35               32
# 18  2001  Arunachal Pradesh   Arunachal District 5    23               15
# 19  2001  Arunachal Pradesh   Arunachal District 6    20               21
# 20  2001  Arunachal Pradesh   Arunachal District 7    23               12
# 21  2001  Arunachal Pradesh   Arunachal District 8    18               15
# 22  2001  Arunachal Pradesh   Arunachal District 9    23               20
# 23  2001  Arunachal Pradesh  Arunachal District 10    17               17
# 24  2001  Arunachal Pradesh  Arunachal District 11    20               16
# 25  2001              Assam       Assam District 1     4                5
# 26  2001              Assam       Assam District 2     8                6
# 27  2001              Assam       Assam District 3     3                4
# 28  2001              Assam       Assam District 4     1                7
# 29  2001              Assam       Assam District 5     5                6
#
#     gang_rape  murder_with_rape  kidnapping_and_abduction  dowry_deaths  \
# 0           3                 5                        11             4
# 1           5                 6                         9             4
# 2           4                 7                        13             5
# 3           4                 7                        20             1
# 4           4                 9                        15             4
# 5           4                 6                        15             4
# 6           5                 5                        16             3
# 7           2                 3                        11             7
# 8           6                 7                        12             2
# 9           2                 3                        11             6
# 10          3                 3                         9             4
# 11          0                10                        15             3
# 12          3                 4                        23             1
# 13          6                 4                        12             5
# 14         16                21                        21            23
# 15         14                18                        31            21
# 16         26                23                        32            19
# 17         15                16                        27            15
# 18         16                25                        37            23
# 19         22                20                        37            15
# 20         25                22                        32            20
# 21         20                17                        33            17
# 22         15                18                        31            18
# 23         22                19                        28            21
# 24         20                16                        34            18
# 25          3                 4                        12             3
# 26         12                 4                        20             1
# 27          4                 5                        15             9
# 28          3                 6                        18             8
# 29          6                 6                        17             5
#
#     dowry_prohibition_act  ...  abduction_for_illicit_intercourse  \
# 0                      12  ...                                  8
# 1                       5  ...                                  4
# 2                       5  ...                                  2
# 3                       4  ...                                  5
# 4                       7  ...                                  9
# 5                       3  ...                                  7
# 6                       5  ...                                  5
# 7                       5  ...                                  7
# 8                       2  ...                                  6
# 9                       3  ...                                  1
# 10                      7  ...                                  6
# 11                      4  ...                                  8
# 12                      6  ...                                  6
# 13                      6  ...                                  5
# 14                     29  ...                                 22
# 15                     14  ...                                 18
# 16                     18  ...                                 21
# 17                     21  ...                                 29
# 18                     22  ...                                 18
# 19                     25  ...                                 21
# 20                     11  ...                                 15
# 21                     28  ...                                 32
# 22                     17  ...                                 19
# 23                     22  ...                                 23
# 24                     22  ...                                 19
# 25                      6  ...                                  3
# 26                      6  ...                                  6
# 27                      2  ...                                  8
# 28                      9  ...                                  5
# 29                      7  ...                                  5
#
#     attempt_to_kidnap  domestic_violence_act_cases  abetment_to_suicide_women  \
# 0                   8                           10                          4
# 1                   4                            6                          7
# 2                   6                            5                          6
# 3                   5                            6                          7
# 4                   6                            0                          4
# 5                   5                            8                          1
# 6                   9                            7                          8
# 7                   6                            7                          4
# 8                   5                            9                          4
# 9                   5                           10                          5
# 10                  7                            4                          7
# 11                 11                            2                          4
# 12                  5                            4                          7
# 13                  7                            3                          5
# 14                 17                           21                         20
# 15                 22                           25                         25
# 16                 28                           23                         14
# 17                 24                           18                         19
# 18                 25                           20                         22
# 19                 21                           19                         24
# 20                 27                           19                         12
# 21                 19                           14                         18
# 22                 22                           25                         16
# 23                 19                           19                         17
# 24                 22                           17                         24
# 25                  5                            3                          3
# 26                  3                            3                          7
# 27                  3                            7                          6
# 28                  4                            4                          5
# 29                  8                            3                          9
#
#     attempt_to_murder_women  insult_outraging_modesty_other  \
# 0                         4                               5
# 1                         3                               2
# 2                         6                               3
# 3                         6                               7
# 4                         3                               6
# 5                         4                               2
# 6                         4                               3
# 7                         6                               8
# 8                         5                               8
# 9                         9                               1
# 10                        4                               7
# 11                        7                               5
# 12                        7                               4
# 13                        7                               8
# 14                       27                              17
# 15                       22                               8
# 16                       26                              26
# 17                       19                              14
# 18                       21                              24
# 19                       21                              17
# 20                       25                              22
# 21                       20                              19
# 22                       25                              13
# 23                       18                              13
# 24                       17                              18
# 25                        6                               5
# 26                        5                               4
# 27                        5                               3
# 28                       11                               6
# 29                        5                               5
#
#     sexual_harassment_workplace  dowry_harassment  marital_rape_reports  \
# 0                             5                 2                     3
# 1                             4                 7                     6
# 2                             3                 5                     2
# 3                             3                 2                     3
# 4                             8                 0                     3
# 5                             4                 8                     7
# 6                             6                 7                     4
# 7                            11                 6                     2
# 8                             2                 8                     5
# 9                             5                 9                     8
# 10                            8                 6                     4
# 11                            5                 9                     6
# 12                            1                 3                     5
# 13                            9                 5                    11
# 14                           23                14                    27
# 15                           22                16                    23
# 16                           15                20                    18
# 17                           17                21                    21
# 18                           21                 9                    21
# 19                           19                20                    17
# 20                           19                17                    23
# 21                           16                29                    20
# 22                           20                28                    18
# 23                           19                23                    20
# 24                           22                19                    15
# 25                            6                 6                     8
# 26                            4                 7                     9
# 27                            3                 9                     7
# 28                            4                 2                     4
# 29                            8                 6                     4
#
#     total_cases
# 0           512
# 1           497
# 2           511
# 3           476
# 4           506
# 5           507
# 6           497
# 7           451
# 8           494
# 9           474
# 10          455
# 11          520
# 12          495
# 13          535
# 14         1793
# 15         1817
# 16         1885
# 17         1846
# 18         1848
# 19         1833
# 20         1817
# 21         1824
# 22         1925
# 23         1922
# 24         1812
# 25          461
# 26          501
# 27          513
# 28          488
# 29          524
#
# [30 rows x 44 columns]

# %% [markdown]
# ## Now analyse the size and no of content we have in our data and then the statistic information

# %%
print(df.info())
print("*"*70)
print("Size of the dataset is:",df.size)
print("*"*70)
print("Shape of the dataset is:",df.shape)
print("*"*70)
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 44 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   year                                   10000 non-null  int64
#  1   state                                  10000 non-null  object
#  2   district                               10000 non-null  object
#  3   rape                                   10000 non-null  int64
#  4   attempt_to_rape                        10000 non-null  int64
#  5   gang_rape                              10000 non-null  int64
#  6   murder_with_rape                       10000 non-null  int64
#  7   kidnapping_and_abduction               10000 non-null  int64
#  8   dowry_deaths                           10000 non-null  int64
#  9   dowry_prohibition_act                  10000 non-null  int64
#  10  cruelty_by_husband_or_relatives_498A   10000 non-null  int64
#  11  acid_attack                            10000 non-null  int64
#  12  attempt_to_acid_attack                 10000 non-null  int64
#  13  assault_on_women_modesty_354           10000 non-null  int64
#  14  assault_intent_disrobe_354B            10000 non-null  int64
#  15  voyeurism_354C                         10000 non-null  int64
#  16  stalking_354D                          10000 non-null  int64
#  17  insult_to_modesty_509                  10000 non-null  int64
#  18  trafficking                            10000 non-null  int64
#  19  procuration_of_minor_girls             10000 non-null  int64
#  20  importation_of_girls                   10000 non-null  int64
#  21  immoral_traffic_act                    10000 non-null  int64
#  22  indecent_representation_of_women       10000 non-null  int64
#  23  women_killed_in_honour_killing         10000 non-null  int64
#  24  witch_hunting                          10000 non-null  int64
#  25  cyber_crime_obscenity_against_women    10000 non-null  int64
#  26  cyber_stalking_bullying_against_women  10000 non-null  int64
#  27  child_marriage_prohibition_act         10000 non-null  int64
#  28  pocso_rape                             10000 non-null  int64
#  29  pocso_assault                          10000 non-null  int64
#  30  pocso_harassment                       10000 non-null  int64
#  31  pocso_unnatural_offences               10000 non-null  int64
#  32  pocso_other                            10000 non-null  int64
#  33  abduction_for_marriage                 10000 non-null  int64
#  34  abduction_for_illicit_intercourse      10000 non-null  int64
#  35  attempt_to_kidnap                      10000 non-null  int64
#  36  domestic_violence_act_cases            10000 non-null  int64
#  37  abetment_to_suicide_women              10000 non-null  int64
#  38  attempt_to_murder_women                10000 non-null  int64
#  39  insult_outraging_modesty_other         10000 non-null  int64
#  40  sexual_harassment_workplace            10000 non-null  int64
#  41  dowry_harassment                       10000 non-null  int64
#  42  marital_rape_reports                   10000 non-null  int64
#  43  total_cases                            10000 non-null  int64
# dtypes: int64(42), object(2)
# memory usage: 3.4+ MB
# None
# **********************************************************************
# Size of the dataset is: 440000
# **********************************************************************
# Shape of the dataset is: (10000, 44)
# **********************************************************************
#                year          rape  attempt_to_rape     gang_rape  \
# count  10000.000000  10000.000000     10000.000000  10000.000000
# mean    2010.253000     17.861100        17.816000     17.810400
# std        5.631178     10.291045        10.264944     10.236138
# min     2001.000000      0.000000         0.000000      0.000000
# 25%     2005.000000      9.000000         9.000000      9.000000
# 50%     2010.000000     17.000000        17.000000     17.000000
# 75%     2015.000000     25.000000        25.000000     25.000000
# max     2020.000000     55.000000        60.000000     56.000000
#
#        murder_with_rape  kidnapping_and_abduction  dowry_deaths  \
# count      10000.000000               10000.00000  10000.000000
# mean          17.777600                  27.87320     17.844900
# std           10.239728                  10.70823     10.238825
# min            0.000000                   4.00000      0.000000
# 25%            9.000000                  19.00000      9.000000
# 50%           16.000000                  27.00000     17.000000
# 75%           25.000000                  35.00000     25.000000
# max           55.000000                  70.00000     55.000000
#
#        dowry_prohibition_act  cruelty_by_husband_or_relatives_498A  \
# count           10000.000000                          10000.000000
# mean               17.876300                             27.823600
# std                10.198068                             10.773954
# min                 0.000000                              3.000000
# 25%                 9.000000                             19.000000
# 50%                17.000000                             27.000000
# 75%                25.000000                             35.000000
# max                61.000000                             76.000000
#
#         acid_attack  ...  abduction_for_illicit_intercourse  \
# count  10000.000000  ...                       10000.000000
# mean      17.834200  ...                          17.858400
# std       10.299676  ...                          10.270204
# min        0.000000  ...                           0.000000
# 25%        9.000000  ...                           9.000000
# 50%       17.000000  ...                          17.000000
# 75%       25.000000  ...                          25.000000
# max       58.000000  ...                          60.000000
#
#        attempt_to_kidnap  domestic_violence_act_cases  \
# count        10000.00000                 10000.000000
# mean            17.83650                    17.803100
# std             10.24629                    10.221026
# min              0.00000                     0.000000
# 25%              9.00000                     9.000000
# 50%             17.00000                    17.000000
# 75%             25.00000                    25.000000
# max             56.00000                    60.000000
#
#        abetment_to_suicide_women  attempt_to_murder_women  \
# count               10000.000000              10000.00000
# mean                   17.884100                 17.78990
# std                    10.281986                 10.20092
# min                     0.000000                  0.00000
# 25%                     9.000000                  9.00000
# 50%                    17.000000                 17.00000
# 75%                    25.000000                 25.00000
# max                    58.000000                 60.00000
#
#        insult_outraging_modesty_other  sexual_harassment_workplace  \
# count                    10000.000000                 10000.000000
# mean                        17.815500                    17.824800
# std                         10.284942                    10.221847
# min                          0.000000                     0.000000
# 25%                          9.000000                     9.000000
# 50%                         17.000000                    17.000000
# 75%                         25.000000                    25.000000
# max                         59.000000                    57.000000
#
#        dowry_harassment  marital_rape_reports   total_cases
# count      10000.000000          10000.000000  10000.000000
# mean          17.872300             17.804700   1634.724800
# std           10.331547             10.245968    842.604171
# min            0.000000              0.000000    443.000000
# 25%            9.000000              9.000000    793.000000
# 50%           17.000000             17.000000   1581.000000
# 75%           25.000000             25.000000   2261.250000
# max           59.000000             57.000000   3676.000000
#
# [8 rows x 42 columns]

# %% [markdown]
# ## Dataset Analysis Summary 😁
#
# - The dataset contains **10,000 rows** and **44 columns**.
# - Using the `info()` function, we confirmed that there are **no null values** in the dataset. 👍
# - The `describe()` function provides the **statistical analysis** of the data, including measures such as mean, standard deviation, minimum, maximum, and quartiles. 📊

# %%
df.columns
# Out:
# Index(['year', 'state', 'district', 'rape', 'attempt_to_rape', 'gang_rape',
#        'murder_with_rape', 'kidnapping_and_abduction', 'dowry_deaths',
#        'dowry_prohibition_act', 'cruelty_by_husband_or_relatives_498A',
#        'acid_attack', 'attempt_to_acid_attack', 'assault_on_women_modesty_354',
#        'assault_intent_disrobe_354B', 'voyeurism_354C', 'stalking_354D',
#        'insult_to_modesty_509', 'trafficking', 'procuration_of_minor_girls',
#        'importation_of_girls', 'immoral_traffic_act',
#        'indecent_representation_of_women', 'women_killed_in_honour_killing',
#        'witch_hunting', 'cyber_crime_obscenity_against_women',
#        'cyber_stalking_bullying_against_women',
#        'child_marriage_prohibition_act', 'pocso_rape', 'pocso_assault',
#        'pocso_harassment', 'pocso_unnatural_offences', 'pocso_other',
#        'abduction_for_marriage', 'abduction_for_illicit_intercourse',
#        'attempt_to_kidnap', 'domestic_violence_act_cases',
#        'abetment_to_suicide_women', 'attempt_to_murder_women',
#        'insult_outraging_modesty_other', 'sexual_harassment_workplace',
#        'dowry_harassment', 'marital_rape_reports', 'total_cases'],
#       dtype='object')

# %% [markdown]
# ## We have to analyse the datatype of each column

# %% [markdown]
# df.dtype

# %%
df.dtypes
# Out:
# year                                      int64
# state                                    object
# district                                 object
# rape                                      int64
# attempt_to_rape                           int64
# gang_rape                                 int64
# murder_with_rape                          int64
# kidnapping_and_abduction                  int64
# dowry_deaths                              int64
# dowry_prohibition_act                     int64
# cruelty_by_husband_or_relatives_498A      int64
# acid_attack                               int64
# attempt_to_acid_attack                    int64
# assault_on_women_modesty_354              int64
# assault_intent_disrobe_354B               int64
# voyeurism_354C                            int64
# stalking_354D                             int64
# insult_to_modesty_509                     int64
# trafficking                               int64
# procuration_of_minor_girls                int64
# importation_of_girls                      int64
# immoral_traffic_act                       int64
# indecent_representation_of_women          int64
# women_killed_in_honour_killing            int64
# witch_hunting                             int64
# cyber_crime_obscenity_against_women       int64
# cyber_stalking_bullying_against_women     int64
# child_marriage_prohibition_act            int64
# pocso_rape                                int64
# pocso_assault                             int64
# pocso_harassment                          int64
# pocso_unnatural_offences                  int64
# pocso_other                               int64
# abduction_for_marriage                    int64
# abduction_for_illicit_intercourse         int64
# attempt_to_kidnap                         int64
# domestic_violence_act_cases               int64
# abetment_to_suicide_women                 int64
# attempt_to_murder_women                   int64
# insult_outraging_modesty_other            int64
# sexual_harassment_workplace               int64
# dowry_harassment                          int64
# marital_rape_reports                      int64
# total_cases                               int64
# dtype: object

# %% [markdown]
# ##Lets have a look on the skewness of our data

# %% [markdown]
# Firstly lets have a look on skewness<br>
# --Skewness helps data analysts understand the asymmetry of a data distribution, indicating whether extreme values are concentrated on one side of the mean

# %%
skewness = df.skew(numeric_only=True)
skewness
# Out:
# year                                     0.006824
# rape                                     0.520890
# attempt_to_rape                          0.533621
# gang_rape                                0.559385
# murder_with_rape                         0.544564
# kidnapping_and_abduction                 0.479961
# dowry_deaths                             0.518284
# dowry_prohibition_act                    0.538136
# cruelty_by_husband_or_relatives_498A     0.469812
# acid_attack                              0.545617
# attempt_to_acid_attack                   0.533860
# assault_on_women_modesty_354             0.441971
# assault_intent_disrobe_354B              0.552664
# voyeurism_354C                           0.532775
# stalking_354D                            0.563124
# insult_to_modesty_509                    0.514559
# trafficking                              0.547969
# procuration_of_minor_girls               0.532007
# importation_of_girls                     0.553537
# immoral_traffic_act                      0.525546
# indecent_representation_of_women         0.513228
# women_killed_in_honour_killing           0.527994
# witch_hunting                            0.527033
# cyber_crime_obscenity_against_women      0.545949
# cyber_stalking_bullying_against_women    0.515016
# child_marriage_prohibition_act           0.556025
# pocso_rape                               0.526582
# pocso_assault                            0.542816
# pocso_harassment                         0.566727
# pocso_unnatural_offences                 0.546533
# pocso_other                              0.546226
# abduction_for_marriage                   0.545291
# abduction_for_illicit_intercourse        0.549432
# attempt_to_kidnap                        0.526885
# domestic_violence_act_cases              0.559063
# abetment_to_suicide_women                0.558741
# attempt_to_murder_women                  0.533533
# insult_outraging_modesty_other           0.544977
# sexual_harassment_workplace              0.528809
# dowry_harassment                         0.545642
# marital_rape_reports                     0.541792
# total_cases                              0.372521
# dtype: float64

# %% [markdown]
# ## Lets Visualise the skewness

# %%
df.hist(figsize=(25, 20), bins=30, edgecolor='black')
plt.suptitle("Distribution of Features", fontsize=16)
plt.show()

# %% [markdown]
# ## **Univariate  and Bivariate Analysis**

# %% [markdown]
# ## Now we are going to Analyse the total cases in each state of India

# %%
r=df[['state','district','total_cases']]
r.describe()
# Out:
#         total_cases
# count  10000.000000
# mean    1634.724800
# std      842.604171
# min      443.000000
# 25%      793.000000
# 50%     1581.000000
# 75%     2261.250000
# max     3676.000000

# %% [markdown]
# ##For Analysing the total cases in each state we use the group by function
# -grouping total cases by their state<br>
# -Finding the total cases of the state

# %%
r=df.groupby('state')['total_cases'].sum()
r
# Out:
# state
# Andaman and Nicobar Islands                 274535
# Andhra Pradesh                              187089
# Arunachal Pradesh                           445161
# Assam                                       241283
# Bihar                                       876635
# Chandigarh                                  888178
# Chhattisgarh                                484416
# Dadra and Nagar Haveli and Daman and Diu    611507
# Delhi                                       236732
# Goa                                         186520
# Gujarat                                     227607
# Haryana                                     224636
# Himachal Pradesh                            187142
# Jammu and Kashmir                           240948
# Jharkhand                                   728108
# Karnataka                                   335808
# Kerala                                      591354
# Ladakh                                      687954
# Lakshadweep                                 225392
# Madhya Pradesh                              444497
# Maharashtra                                 470311
# Manipur                                     200492
# Meghalaya                                   404514
# Mizoram                                     407988
# Nagaland                                    667720
# Odisha                                      498677
# Puducherry                                  795917
# Punjab                                      956294
# Rajasthan                                   401083
# Sikkim                                      829631
# Tamil Nadu                                  266936
# Telangana                                   889374
# Tripura                                     252904
# Uttar Pradesh                               237442
# Uttarakhand                                 238349
# West Bengal                                 504114
# Name: total_cases, dtype: int64

# %%
r.describe()
# Out:
# count        36.000000
# mean     454090.222222
# std      244171.316812
# min      186520.000000
# 25%      238122.250000
# 50%      406251.000000
# 75%      625560.250000
# max      956294.000000
# Name: total_cases, dtype: float64

# %% [markdown]
# Now from above analysis we saw that the state having minimum and maximum  total case is as follows::

# %%
# State with minimum cases
min_state = r.idxmin()
min_cases = r.min()

# State with maximum cases
max_state = r.idxmax()
max_cases = r.max()

print("State with Minimum Crime Cases:", min_state, "->", min_cases)
print("State with Maximum Crime Cases:", max_state, "->", max_cases)
# Out:
# State with Minimum Crime Cases: Goa -> 186520
# State with Maximum Crime Cases: Punjab -> 956294

# %% [markdown]
# ## Analysing the top10 states whole total crimes is higher then other
# -- Ploting the bar graph after grouping data<br>
# -- Sort_value help us to see the data in descending order

# %%
r=df.groupby('state')['total_cases'].sum().sort_values(ascending=False).head(5)
plt.figure(figsize=(8, 6))
sns.barplot(r,palette="deep")
plt.show()
# Out:
# /tmp/ipython-input-2692999933.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(r,palette="deep")

# %% [markdown]
# ### Distribution of Rape Cases Across States (2001, 2010, 2020)
#
# This histogram shows the **average number of rape cases per state** for the years 2001, 2010, and 2020.
#
#
#
# **Key Takeaways:**
# - Average rape cases per state have **increased over the last 20 years**.
# - Some states consistently report higher numbers — these may need **focused attention**.
# - The trend may reflect **better reporting, increased awareness, or actual rise in incidents**.

# %%
d1 = df.groupby(['year','state'], as_index=False)['rape'].mean()
subset = d1[d1['year'].isin([2001, 2010, 2020])]
sns.histplot(data=subset, x='rape', hue='year', bins=30, element="step",palette='dark')
plt.title("Distribution of rape cases for selected years")
plt.show()

# %% [markdown]
# ### Trend of Average Rape Cases per State (2001–2021)
#
# This line plot shows the **average number of rape cases per state** for each year from 2001 to 2021.
#
# **Observations:**
# - There is a **gradual increase** in average cases over the 21-year period.
# - **Early 2000s (2001–2005):** Lower average cases, indicating fewer reported incidents or lower reporting.
# - **2010–2015:** A noticeable rise, possibly due to improved reporting mechanisms or increased awareness.
# - **2016–2021:** The trend continues upward, suggesting either a real increase in cases or better data collection.
# - The plot highlights **year-to-year variations**, but the overall trend is clearly **increasing**.
#
# **Key Takeaways:**
# - Average rape cases per state have **risen consistently over two decades**.
# - The upward trend may reflect **better reporting, awareness campaigns, or actual increase in incidents**.
# - This analysis helps identify **long-term trends** rather than individual state variations.

# %%
trend = d1.groupby('year')['rape'].mean().reset_index()
sns.lineplot(data=trend, x='year', y='rape', marker='o', color="crimson")
plt.title("Average rape cases  per year (2001–2021)")
plt.show()

# %% [markdown]
# ### Share of Selected Crimes in 2020
#
# This pie chart shows the **distribution of four major crime categories** against women in 2020:
#
# - **Rape**
# - **Dowry Deaths**
# - **Domestic Violence Act Cases**
# - **Cruelty by Husband or Relatives (498A)**
#
# **Observations:**
# - The largest slice represents the crime with the **highest number of reported cases** among the selected categories.
# - Smaller slices indicate **less frequent but still significant crimes**.
# - The pie chart helps understand **which types of crimes contribute most to the overall burden** in 2020.
#
# **Key Takeaways:**
# - Rape or Domestic Violence-related cases may dominate the share, highlighting **critical areas for policy and awareness**.
# - Even smaller slices like Dowry Deaths and Cruelty under 498A are important and **require attention**.
# - Such proportion-based visualization complements line and histogram plots by **showing composition rather than trend**.

# %%
year_data = df[df['year'] == 2020]
selected = year_data[['rape','dowry_deaths','domestic_violence_act_cases','cruelty_by_husband_or_relatives_498A']].sum()

plt.figure(figsize=(6,6))
plt.pie(selected, labels=selected.index, autopct='%1.1f%%', colors=['tomato','gold','skyblue','Pink'])
plt.title("Selected crimes share in 2020")
plt.show()

# %% [markdown]
# ### Distribution of Total Women-related Crime Cases Across States (2018–2020)
#
# This boxplot shows the **distribution of total women-related crime cases** per state for the years **2018, 2019, and 2020**.
#
# **Observations:**
# - Each box represents the **spread of total cases** across all states for that year.
# - The **central line in each box** shows the **median number of cases**.
#   - A rising median over the years indicates an **overall increase in reported crimes**.
# - The **height of the box** (interquartile range, Q1–Q3) shows the **variation among states**.
#   - Wider boxes indicate more disparity; narrower boxes indicate more uniform reporting.
# - **Whiskers** represent the **minimum and maximum within 1.5×IQR**.
# - **Dots outside the whiskers** are **outlier states** with unusually high or low total crime cases.

# %%
plt.figure(figsize=(10,6))
d1 = df[df['year'].isin([2018, 2019, 2020])]

sns.boxplot(data=d1, x='year', y='total_cases')
plt.xticks(rotation=90)
plt.title(" Distribution of Total Women-related Crime Cases Across States in 2019")
plt.ylabel("Total Cases per State")
plt.show()

# %% [markdown]
# ##Dowry Death and Domestic Violance cases

# %% [markdown]
# ## 🔥 Heatmap Analysis of Dowry Deaths (State vs Year)
#
# The heatmap above shows the **distribution of dowry deaths across different states and years**.
# - Darker shades represent **higher numbers of dowry deaths**, while lighter shades represent **fewer cases**.
# - This visualization makes it easier to identify **regional and temporal patterns**:
#   - Some states consistently show darker shades across years, indicating **persistently high dowry death cases**.
#   - A few states show **gradual decline or increase** in cases over the years.
#   - States with very light colors have **lower incidence** of dowry-related deaths.

# %%
# 4. Heatmap (State vs Year)
heatmap_data = df.pivot_table(index="state", columns="year", values="dowry_deaths", aggfunc="sum")
plt.figure(figsize=(15,10))
sns.heatmap(heatmap_data, cmap="Reds", linewidths=1.5)
plt.title("Heatmap of Dowry Deaths (State vs Year)", fontsize=16)
plt.show()

# %% [markdown]
# ## Now this will help us to analyse:
# - That in past few year do our security and system helps to reduce the domestic violance in womens even
# - Even having wast education have these cases get reduced

# %%
data=df[df['year'].isin([2018,2019,2020])]
data=data.groupby(['state', 'year'])['domestic_violence_act_cases'].mean().reset_index()
data
# Out:
#                           state  year  domestic_violence_act_cases
# 0   Andaman and Nicobar Islands  2018                    14.461538
# 1   Andaman and Nicobar Islands  2019                    13.000000
# 2                Andhra Pradesh  2018                     6.642857
# 3                Andhra Pradesh  2019                     9.428571
# 4                Andhra Pradesh  2020                     9.428571
# ..                          ...   ...                          ...
# 86                Uttar Pradesh  2019                    20.000000
# 87                  Uttarakhand  2018                     9.736842
# 88                  Uttarakhand  2019                     8.105263
# 89                  West Bengal  2018                    20.235294
# 90                  West Bengal  2019                    19.235294
#
# [91 rows x 3 columns]

# %% [markdown]
# ## Line bar will help us to analyse the data
# -We had grouped the data with respect to the state and year
# -After having the mean lets analyse the data

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x='year',y='domestic_violence_act_cases',data=data)
plt.title("Average of domestic violance cases per year")
plt.show()

# %% [markdown]
# ## 📊 Heatmap of Domestic Violence Act Cases (2018–2020)
#
# In this visualization, we created a **pivot table** of states (rows) versus years (columns: 2018, 2019, 2020) and plotted a **heatmap**.
#
# ### 🔹 Why are we doing this?
# - To compare **state-wise domestic violence cases across multiple years** in one single chart.
# - Heatmap helps us quickly identify where the values are **high (darker shades)** and **low (lighter shades)** without scrolling through large tables.
# - Instead of checking each state separately, we can **visually detect patterns and outliers**.
#
# ### 🔹 What insights do we get?
# - **States with consistently darker shades** across 2018–2020 → these states have **persistently high domestic violence cases**.
# - **Lighter shades** indicate states with relatively fewer cases.
# - By comparing columns (years), we can observe if cases are **increasing, decreasing, or stable** across time.
# - It gives both a **spatial (state-wise)** and **temporal (year-wise)** perspective.
#
# 👉 Overall, this heatmap allows us to **pinpoint which states need urgent attention** in terms of domestic violence cases and also whether the situation is improving or worsening over time.

# %%
plt.figure(figsize=(10,8))
pivot=df.pivot_table(index='state',columns='year',values='domestic_violence_act_cases',aggfunc='mean')
pivot = pivot.loc[:, [2018, 2019, 2020]]
sns.heatmap(data=pivot,cmap='Blues',linewidths=1.5)
plt.title("State having maximum Domestic Violance Cases in year 2018,2019,2020")
plt.show()

# %% [markdown]
# ## 💥 Analysis of Acid Attack Cases (2018–2020)
#
# Acid attacks are among the most brutal crimes against women. They not only cause **severe physical injuries and disfigurement** but also leave victims with **lifelong trauma**, affecting their ability to move freely, feel safe, and live independently.
#
# ### 🔹 Why are we analyzing this?
# - Acid attacks directly **restrict women’s freedom** in public spaces, as fear of such crimes can discourage women from education, employment, and social participation.
# - By studying the **state-wise and year-wise trend**, we can identify **regions with higher risk** and track whether the situation is improving or worsening over time.
# - It highlights **where stricter law enforcement, awareness programs, and victim support** are most urgently needed.
#
# ### 🔹 What does the grouped data show?
# - We have grouped the dataset by **state and year (2018–2020)** to calculate the **average number of acid attack cases**.
# - This grouping helps us compare how different states perform over the years and locate the **hotspots of the crime**.
# - A further visualization (heatmap or barplot) will make these differences even clearer.
#
# 👉 Overall, analyzing acid attack data is crucial for understanding the **threat landscape faced by women**, and it guides **policy makers, NGOs,**

# %%
# data=df[df['year'].isin([2018,2019,2020])]
data=df.groupby(['state', 'year'])['acid_attack'].mean().reset_index()
data
# Out:
#                            state  year  acid_attack
# 0    Andaman and Nicobar Islands  2001     9.615385
# 1    Andaman and Nicobar Islands  2002     8.692308
# 2    Andaman and Nicobar Islands  2003     9.538462
# 3    Andaman and Nicobar Islands  2004    10.307692
# 4    Andaman and Nicobar Islands  2005    12.076923
# ..                           ...   ...          ...
# 698                  West Bengal  2015    18.529412
# 699                  West Bengal  2016    18.529412
# 700                  West Bengal  2017    18.294118
# 701                  West Bengal  2018    19.235294
# 702                  West Bengal  2019    16.764706
#
# [703 rows x 3 columns]

# %%
sns.lineplot(x='year',y='acid_attack',data=data)
plt.title("Average of acid attack cases per year")
plt.show()

# %% [markdown]
# The line chart above represents the **average number of acid attack cases reported each year**.
#
# ### 🔹 Why this visualization?
# - Using a **line chart** helps us observe the **trend of acid attacks over time**.
# - It gives a clear view of whether the crime rate is **increasing, decreasing, or staying stable** year by year.
#
# ### 🔹 Key Insights
# - Each point on the line corresponds to the **mean value of acid attack cases** for that particular year.
# - A **rising line** suggests that the problem is worsening and requires urgent intervention.
# - A **falling line** indicates that stricter laws, awareness, or enforcement may be having a positive effect.

# %%
df.columns
# Out:
# Index(['year', 'state', 'district', 'rape', 'attempt_to_rape', 'gang_rape',
#        'murder_with_rape', 'kidnapping_and_abduction', 'dowry_deaths',
#        'dowry_prohibition_act', 'cruelty_by_husband_or_relatives_498A',
#        'acid_attack', 'attempt_to_acid_attack', 'assault_on_women_modesty_354',
#        'assault_intent_disrobe_354B', 'voyeurism_354C', 'stalking_354D',
#        'insult_to_modesty_509', 'trafficking', 'procuration_of_minor_girls',
#        'importation_of_girls', 'immoral_traffic_act',
#        'indecent_representation_of_women', 'women_killed_in_honour_killing',
#        'witch_hunting', 'cyber_crime_obscenity_against_women',
#        'cyber_stalking_bullying_against_women',
#        'child_marriage_prohibition_act', 'pocso_rape', 'pocso_assault',
#        'pocso_harassment', 'pocso_unnatural_offences', 'pocso_other',
#        'abduction_for_marriage', 'abduction_for_illicit_intercourse',
#        'attempt_to_kidnap', 'domestic_violence_act_cases',
#        'abetment_to_suicide_women', 'attempt_to_murder_women',
#        'insult_outraging_modesty_other', 'sexual_harassment_workplace',
#        'dowry_harassment', 'marital_rape_reports', 'total_cases'],
#       dtype='object')

# %%
r=df.groupby('state')['sexual_harassment_workplace'].mean().reset_index().sort_values(by='sexual_harassment_workplace',ascending=False)
r=r.head(10)
r
# Out:
#              state  sexual_harassment_workplace
# 29          Sikkim                    37.287449
# 27          Punjab                    36.400000
# 25          Odisha                    32.719298
# 4            Bihar                    32.090000
# 24        Nagaland                    31.873362
# 26      Puducherry                    27.176471
# 31       Telangana                    26.833795
# 16          Kerala                    26.700000
# 5       Chandigarh                    26.648199
# 19  Madhya Pradesh                    22.440909

# %% [markdown]
# ## Workplace Harassment Cases Across States (2018–2020)
#
# This bar plot visualizes the **total reported cases of sexual harassment in the workplace** for each state in the years **2018, 2019, and 2020**.
#
# ### 🔹 What does the code do?
# - It calculates the **sum of 'sexual_harassment_workplace' cases** for each state and year (2018-2020).
# - It then creates a **bar plot** where:
#   - The **x-axis** represents each **state**.
#   - The **y-axis** shows the **total number of workplace harassment cases**.
#   - Different colored bars within each state represent the data for the years **2018, 2019, and 2020**, making it easy to compare yearly trends within a state.
#
# ### 🔹 Why this visualization?
# - **State-wise comparison:** Quickly compare which states report higher or lower numbers of workplace harassment cases.
# - **Yearly trend within states:** Observe if cases are increasing, decreasing, or staying stable within specific states over the three years.
# - **Identification of hotspots:** Pinpoint states with consistently high numbers, indicating areas that may require more targeted interventions.
#
# ### 🔹 Key Insights
# - The height of the bars shows the **magnitude of the problem** in each state.
# - Comparing the bars for different years within a state helps understand the **short-term trend**.
# - This plot can help **allocate resources** and design **awareness campaigns or policy changes** more effectively based on state-specific needs.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cases = df.groupby(['year',"state"])["sexual_harassment_workplace"].sum().reset_index()
cases=cases[cases['year'].isin([2018,2019,2020])].sort_values(by='sexual_harassment_workplace',ascending=False)
# cases=cases.head(10)
plt.figure(figsize=(10,8))
sns.barplot(
    data=cases,
    y="state",
    x="sexual_harassment_workplace",
    hue="year",
    palette=sns.color_palette("viridis", n_colors=3)
)

plt.title("Workplace Harassment Cases by State")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #Finding Coorelation

# %%
numeric_df = df.select_dtypes(include='number')
numeric_df.head()
# Out:
#    year  rape  attempt_to_rape  gang_rape  murder_with_rape  \
# 0  2001     3                7          3                 5
# 1  2001     3                4          5                 6
# 2  2001     3                6          4                 7
# 3  2001     2                8          4                 7
# 4  2001     2                7          4                 9
#
#    kidnapping_and_abduction  dowry_deaths  dowry_prohibition_act  \
# 0                        11             4                     12
# 1                         9             4                      5
# 2                        13             5                      5
# 3                        20             1                      4
# 4                        15             4                      7
#
#    cruelty_by_husband_or_relatives_498A  acid_attack  ...  \
# 0                                    16            3  ...
# 1                                    12            7  ...
# 2                                    12            7  ...
# 3                                    19            3  ...
# 4                                    17            2  ...
#
#    abduction_for_illicit_intercourse  attempt_to_kidnap  \
# 0                                  8                  8
# 1                                  4                  4
# 2                                  2                  6
# 3                                  5                  5
# 4                                  9                  6
#
#    domestic_violence_act_cases  abetment_to_suicide_women  \
# 0                           10                          4
# 1                            6                          7
# 2                            5                          6
# 3                            6                          7
# 4                            0                          4
#
#    attempt_to_murder_women  insult_outraging_modesty_other  \
# 0                        4                               5
# 1                        3                               2
# 2                        6                               3
# 3                        6                               7
# 4                        3                               6
#
#    sexual_harassment_workplace  dowry_harassment  marital_rape_reports  \
# 0                            5                 2                     3
# 1                            4                 7                     6
# 2                            3                 5                     2
# 3                            3                 2                     3
# 4                            8                 0                     3
#
#    total_cases
# 0          512
# 1          497
# 2          511
# 3          476
# 4          506
#
# [5 rows x 42 columns]

# %%
numeric_df.corr()
# Out:
#                                            year      rape  attempt_to_rape  \
# year                                   1.000000  0.095876         0.094939
# rape                                   0.095876  1.000000         0.831399
# attempt_to_rape                        0.094939  0.831399         1.000000
# gang_rape                              0.098451  0.832944         0.830568
# murder_with_rape                       0.100041  0.834027         0.826352
# kidnapping_and_abduction               0.091954  0.795202         0.787224
# dowry_deaths                           0.094582  0.834726         0.830546
# dowry_prohibition_act                  0.097343  0.831918         0.828341
# cruelty_by_husband_or_relatives_498A   0.095344  0.798558         0.789843
# acid_attack                            0.087354  0.833617         0.827228
# attempt_to_acid_attack                 0.094563  0.831151         0.828068
# assault_on_women_modesty_354           0.096202  0.798431         0.791557
# assault_intent_disrobe_354B            0.095122  0.834288         0.827879
# voyeurism_354C                         0.092571  0.834190         0.826180
# stalking_354D                          0.094209  0.831146         0.831648
# insult_to_modesty_509                  0.106881  0.830769         0.824159
# trafficking                            0.104971  0.833426         0.827243
# procuration_of_minor_girls             0.091930  0.835492         0.828542
# importation_of_girls                   0.094993  0.835855         0.828082
# immoral_traffic_act                    0.095862  0.835030         0.828141
# indecent_representation_of_women       0.090863  0.834605         0.829351
# women_killed_in_honour_killing         0.101941  0.836867         0.830183
# witch_hunting                          0.097318  0.833605         0.831826
# cyber_crime_obscenity_against_women    0.103193  0.828667         0.825747
# cyber_stalking_bullying_against_women  0.100111  0.834196         0.831145
# child_marriage_prohibition_act         0.096001  0.835250         0.832806
# pocso_rape                             0.093141  0.830991         0.831405
# pocso_assault                          0.098055  0.838199         0.828738
# pocso_harassment                       0.088005  0.831610         0.828410
# pocso_unnatural_offences               0.093699  0.833231         0.827342
# pocso_other                            0.098929  0.833898         0.829423
# abduction_for_marriage                 0.089131  0.830417         0.827946
# abduction_for_illicit_intercourse      0.097623  0.832273         0.827630
# attempt_to_kidnap                      0.089348  0.835158         0.830717
# domestic_violence_act_cases            0.100970  0.831186         0.826838
# abetment_to_suicide_women              0.095708  0.833860         0.828310
# attempt_to_murder_women                0.089935  0.833680         0.831410
# insult_outraging_modesty_other         0.102501  0.832744         0.828100
# sexual_harassment_workplace            0.090805  0.832418         0.830952
# dowry_harassment                       0.092736  0.834665         0.831171
# marital_rape_reports                   0.093429  0.832676         0.825845
# total_cases                            0.106338  0.915718         0.910316
#
#                                        gang_rape  murder_with_rape  \
# year                                    0.098451          0.100041
# rape                                    0.832944          0.834027
# attempt_to_rape                         0.830568          0.826352
# gang_rape                               1.000000          0.830875
# murder_with_rape                        0.830875          1.000000
# kidnapping_and_abduction                0.793889          0.788850
# dowry_deaths                            0.830968          0.832544
# dowry_prohibition_act                   0.831925          0.828389
# cruelty_by_husband_or_relatives_498A    0.790071          0.793984
# acid_attack                             0.828863          0.828111
# attempt_to_acid_attack                  0.832378          0.826651
# assault_on_women_modesty_354            0.792306          0.792245
# assault_intent_disrobe_354B             0.829066          0.830294
# voyeurism_354C                          0.827944          0.829730
# stalking_354D                           0.828256          0.827735
# insult_to_modesty_509                   0.832993          0.829838
# trafficking                             0.829466          0.831729
# procuration_of_minor_girls              0.833416          0.830806
# importation_of_girls                    0.829060          0.832299
# immoral_traffic_act                     0.832601          0.835765
# indecent_representation_of_women        0.829592          0.832324
# women_killed_in_honour_killing          0.829581          0.832847
# witch_hunting                           0.832386          0.832100
# cyber_crime_obscenity_against_women     0.829270          0.827902
# cyber_stalking_bullying_against_women   0.833944          0.833839
# child_marriage_prohibition_act          0.833337          0.835179
# pocso_rape                              0.831814          0.827369
# pocso_assault                           0.835095          0.834340
# pocso_harassment                        0.833165          0.834000
# pocso_unnatural_offences                0.828790          0.829207
# pocso_other                             0.832856          0.829723
# abduction_for_marriage                  0.829664          0.829186
# abduction_for_illicit_intercourse       0.828369          0.828443
# attempt_to_kidnap                       0.829117          0.829702
# domestic_violence_act_cases             0.828877          0.827894
# abetment_to_suicide_women               0.829156          0.829079
# attempt_to_murder_women                 0.835480          0.829606
# insult_outraging_modesty_other          0.830304          0.829215
# sexual_harassment_workplace             0.831900          0.829466
# dowry_harassment                        0.828729          0.831096
# marital_rape_reports                    0.836286          0.830816
# total_cases                             0.912711          0.912118
#
#                                        kidnapping_and_abduction  dowry_deaths  \
# year                                                   0.091954      0.094582
# rape                                                   0.795202      0.834726
# attempt_to_rape                                        0.787224      0.830546
# gang_rape                                              0.793889      0.830968
# murder_with_rape                                       0.788850      0.832544
# kidnapping_and_abduction                               1.000000      0.792300
# dowry_deaths                                           0.792300      1.000000
# dowry_prohibition_act                                  0.786936      0.832401
# cruelty_by_husband_or_relatives_498A                   0.757979      0.800408
# acid_attack                                            0.788677      0.828808
# attempt_to_acid_attack                                 0.792536      0.831186
# assault_on_women_modesty_354                           0.761225      0.794603
# assault_intent_disrobe_354B                            0.789049      0.829847
# voyeurism_354C                                         0.791904      0.830642
# stalking_354D                                          0.789928      0.829010
# insult_to_modesty_509                                  0.793829      0.831895
# trafficking                                            0.791939      0.831200
# procuration_of_minor_girls                             0.793227      0.829095
# importation_of_girls                                   0.793915      0.830730
# immoral_traffic_act                                    0.794138      0.835440
# indecent_representation_of_women                       0.792191      0.832963
# women_killed_in_honour_killing                         0.788315      0.831442
# witch_hunting                                          0.794996      0.831734
# cyber_crime_obscenity_against_women                    0.787864      0.831610
# cyber_stalking_bullying_against_women                  0.793817      0.834298
# child_marriage_prohibition_act                         0.791625      0.831392
# pocso_rape                                             0.792982      0.828535
# pocso_assault                                          0.793828      0.835561
# pocso_harassment                                       0.792863      0.834235
# pocso_unnatural_offences                               0.787277      0.834214
# pocso_other                                            0.792350      0.829663
# abduction_for_marriage                                 0.786419      0.828669
# abduction_for_illicit_intercourse                      0.790652      0.831390
# attempt_to_kidnap                                      0.796638      0.831676
# domestic_violence_act_cases                            0.793134      0.831077
# abetment_to_suicide_women                              0.791817      0.832663
# attempt_to_murder_women                                0.795503      0.833712
# insult_outraging_modesty_other                         0.790211      0.830214
# sexual_harassment_workplace                            0.788178      0.828178
# dowry_harassment                                       0.791226      0.833408
# marital_rape_reports                                   0.790315      0.832886
# total_cases                                            0.870920      0.913032
#
#                                        dowry_prohibition_act  \
# year                                                0.097343
# rape                                                0.831918
# attempt_to_rape                                     0.828341
# gang_rape                                           0.831925
# murder_with_rape                                    0.828389
# kidnapping_and_abduction                            0.786936
# dowry_deaths                                        0.832401
# dowry_prohibition_act                               1.000000
# cruelty_by_husband_or_relatives_498A                0.793886
# acid_attack                                         0.826826
# attempt_to_acid_attack                              0.828213
# assault_on_women_modesty_354                        0.790755
# assault_intent_disrobe_354B                         0.828133
# voyeurism_354C                                      0.828481
# stalking_354D                                       0.829417
# insult_to_modesty_509                               0.827646
# trafficking                                         0.826004
# procuration_of_minor_girls                          0.829810
# importation_of_girls                                0.828893
# immoral_traffic_act                                 0.829620
# indecent_representation_of_women                    0.828522
# women_killed_in_honour_killing                      0.829490
# witch_hunting                                       0.831612
# cyber_crime_obscenity_against_women                 0.829062
# cyber_stalking_bullying_against_women               0.832930
# child_marriage_prohibition_act                      0.832122
# pocso_rape                                          0.830913
# pocso_assault                                       0.831634
# pocso_harassment                                    0.826606
# pocso_unnatural_offences                            0.828670
# pocso_other                                         0.827412
# abduction_for_marriage                              0.828928
# abduction_for_illicit_intercourse                   0.827157
# attempt_to_kidnap                                   0.830280
# domestic_violence_act_cases                         0.827809
# abetment_to_suicide_women                           0.830102
# attempt_to_murder_women                             0.829479
# insult_outraging_modesty_other                      0.827110
# sexual_harassment_workplace                         0.831314
# dowry_harassment                                    0.829080
# marital_rape_reports                                0.828062
# total_cases                                         0.910956
#
#                                        cruelty_by_husband_or_relatives_498A  \
# year                                                               0.095344
# rape                                                               0.798558
# attempt_to_rape                                                    0.789843
# gang_rape                                                          0.790071
# murder_with_rape                                                   0.793984
# kidnapping_and_abduction                                           0.757979
# dowry_deaths                                                       0.800408
# dowry_prohibition_act                                              0.793886
# cruelty_by_husband_or_relatives_498A                               1.000000
# acid_attack                                                        0.791298
# attempt_to_acid_attack                                             0.797607
# assault_on_women_modesty_354                                       0.761778
# assault_intent_disrobe_354B                                        0.792021
# voyeurism_354C                                                     0.791651
# stalking_354D                                                      0.793596
# insult_to_modesty_509                                              0.793611
# trafficking                                                        0.791610
# procuration_of_minor_girls                                         0.793268
# importation_of_girls                                               0.793983
# immoral_traffic_act                                                0.793801
# indecent_representation_of_women                                   0.794865
# women_killed_in_honour_killing                                     0.792594
# witch_hunting                                                      0.795098
# cyber_crime_obscenity_against_women                                0.789358
# cyber_stalking_bullying_against_women                              0.799265
# child_marriage_prohibition_act                                     0.793376
# pocso_rape                                                         0.794541
# pocso_assault                                                      0.797938
# pocso_harassment                                                   0.793968
# pocso_unnatural_offences                                           0.791531
# pocso_other                                                        0.795302
# abduction_for_marriage                                             0.791251
# abduction_for_illicit_intercourse                                  0.794670
# attempt_to_kidnap                                                  0.790593
# domestic_violence_act_cases                                        0.797138
# abetment_to_suicide_women                                          0.795403
# attempt_to_murder_women                                            0.797165
# insult_outraging_modesty_other                                     0.792299
# sexual_harassment_workplace                                        0.793854
# dowry_harassment                                                   0.797284
# marital_rape_reports                                               0.791693
# total_cases                                                        0.873251
#
#                                        acid_attack  ...  \
# year                                      0.087354  ...
# rape                                      0.833617  ...
# attempt_to_rape                           0.827228  ...
# gang_rape                                 0.828863  ...
# murder_with_rape                          0.828111  ...
# kidnapping_and_abduction                  0.788677  ...
# dowry_deaths                              0.828808  ...
# dowry_prohibition_act                     0.826826  ...
# cruelty_by_husband_or_relatives_498A      0.791298  ...
# acid_attack                               1.000000  ...
# attempt_to_acid_attack                    0.826761  ...
# assault_on_women_modesty_354              0.791710  ...
# assault_intent_disrobe_354B               0.827757  ...
# voyeurism_354C                            0.828404  ...
# stalking_354D                             0.828375  ...
# insult_to_modesty_509                     0.829118  ...
# trafficking                               0.826544  ...
# procuration_of_minor_girls                0.827465  ...
# importation_of_girls                      0.827272  ...
# immoral_traffic_act                       0.830739  ...
# indecent_representation_of_women          0.828123  ...
# women_killed_in_honour_killing            0.829839  ...
# witch_hunting                             0.829480  ...
# cyber_crime_obscenity_against_women       0.828094  ...
# cyber_stalking_bullying_against_women     0.830617  ...
# child_marriage_prohibition_act            0.831041  ...
# pocso_rape                                0.831285  ...
# pocso_assault                             0.831720  ...
# pocso_harassment                          0.827859  ...
# pocso_unnatural_offences                  0.827616  ...
# pocso_other                               0.827705  ...
# abduction_for_marriage                    0.829039  ...
# abduction_for_illicit_intercourse         0.830196  ...
# attempt_to_kidnap                         0.827252  ...
# domestic_violence_act_cases               0.822789  ...
# abetment_to_suicide_women                 0.827028  ...
# attempt_to_murder_women                   0.825506  ...
# insult_outraging_modesty_other            0.826948  ...
# sexual_harassment_workplace               0.829173  ...
# dowry_harassment                          0.826012  ...
# marital_rape_reports                      0.827215  ...
# total_cases                               0.910116  ...
#
#                                        abduction_for_illicit_intercourse  \
# year                                                            0.097623
# rape                                                            0.832273
# attempt_to_rape                                                 0.827630
# gang_rape                                                       0.828369
# murder_with_rape                                                0.828443
# kidnapping_and_abduction                                        0.790652
# dowry_deaths                                                    0.831390
# dowry_prohibition_act                                           0.827157
# cruelty_by_husband_or_relatives_498A                            0.794670
# acid_attack                                                     0.830196
# attempt_to_acid_attack                                          0.829472
# assault_on_women_modesty_354                                    0.793756
# assault_intent_disrobe_354B                                     0.829326
# voyeurism_354C                                                  0.834071
# stalking_354D                                                   0.827737
# insult_to_modesty_509                                           0.828512
# trafficking                                                     0.830434
# procuration_of_minor_girls                                      0.832753
# importation_of_girls                                            0.828574
# immoral_traffic_act                                             0.834033
# indecent_representation_of_women                                0.828322
# women_killed_in_honour_killing                                  0.830906
# witch_hunting                                                   0.833418
# cyber_crime_obscenity_against_women                             0.827716
# cyber_stalking_bullying_against_women                           0.834323
# child_marriage_prohibition_act                                  0.830389
# pocso_rape                                                      0.831413
# pocso_assault                                                   0.832090
# pocso_harassment                                                0.830405
# pocso_unnatural_offences                                        0.829775
# pocso_other                                                     0.831212
# abduction_for_marriage                                          0.827367
# abduction_for_illicit_intercourse                               1.000000
# attempt_to_kidnap                                               0.831979
# domestic_violence_act_cases                                     0.827835
# abetment_to_suicide_women                                       0.832106
# attempt_to_murder_women                                         0.832482
# insult_outraging_modesty_other                                  0.823461
# sexual_harassment_workplace                                     0.832057
# dowry_harassment                                                0.832450
# marital_rape_reports                                            0.827284
# total_cases                                                     0.912282
#
#                                        attempt_to_kidnap  \
# year                                            0.089348
# rape                                            0.835158
# attempt_to_rape                                 0.830717
# gang_rape                                       0.829117
# murder_with_rape                                0.829702
# kidnapping_and_abduction                        0.796638
# dowry_deaths                                    0.831676
# dowry_prohibition_act                           0.830280
# cruelty_by_husband_or_relatives_498A            0.790593
# acid_attack                                     0.827252
# attempt_to_acid_attack                          0.832185
# assault_on_women_modesty_354                    0.795000
# assault_intent_disrobe_354B                     0.828045
# voyeurism_354C                                  0.832403
# stalking_354D                                   0.832276
# insult_to_modesty_509                           0.830157
# trafficking                                     0.829642
# procuration_of_minor_girls                      0.835198
# importation_of_girls                            0.829099
# immoral_traffic_act                             0.832834
# indecent_representation_of_women                0.831339
# women_killed_in_honour_killing                  0.833106
# witch_hunting                                   0.832180
# cyber_crime_obscenity_against_women             0.830180
# cyber_stalking_bullying_against_women           0.835154
# child_marriage_prohibition_act                  0.831451
# pocso_rape                                      0.831153
# pocso_assault                                   0.834986
# pocso_harassment                                0.832898
# pocso_unnatural_offences                        0.830538
# pocso_other                                     0.833068
# abduction_for_marriage                          0.831078
# abduction_for_illicit_intercourse               0.831979
# attempt_to_kidnap                               1.000000
# domestic_violence_act_cases                     0.832386
# abetment_to_suicide_women                       0.829178
# attempt_to_murder_women                         0.831256
# insult_outraging_modesty_other                  0.825223
# sexual_harassment_workplace                     0.831668
# dowry_harassment                                0.830229
# marital_rape_reports                            0.830125
# total_cases                                     0.912938
#
#                                        domestic_violence_act_cases  \
# year                                                      0.100970
# rape                                                      0.831186
# attempt_to_rape                                           0.826838
# gang_rape                                                 0.828877
# murder_with_rape                                          0.827894
# kidnapping_and_abduction                                  0.793134
# dowry_deaths                                              0.831077
# dowry_prohibition_act                                     0.827809
# cruelty_by_husband_or_relatives_498A                      0.797138
# acid_attack                                               0.822789
# attempt_to_acid_attack                                    0.828760
# assault_on_women_modesty_354                              0.792383
# assault_intent_disrobe_354B                               0.830802
# voyeurism_354C                                            0.828265
# stalking_354D                                             0.827530
# insult_to_modesty_509                                     0.828864
# trafficking                                               0.826178
# procuration_of_minor_girls                                0.830316
# importation_of_girls                                      0.830240
# immoral_traffic_act                                       0.830586
# indecent_representation_of_women                          0.830832
# women_killed_in_honour_killing                            0.830825
# witch_hunting                                             0.832931
# cyber_crime_obscenity_against_women                       0.827516
# cyber_stalking_bullying_against_women                     0.832478
# child_marriage_prohibition_act                            0.829519
# pocso_rape                                                0.831468
# pocso_assault                                             0.830116
# pocso_harassment                                          0.831122
# pocso_unnatural_offences                                  0.827043
# pocso_other                                               0.830528
# abduction_for_marriage                                    0.826234
# abduction_for_illicit_intercourse                         0.827835
# attempt_to_kidnap                                         0.832386
# domestic_violence_act_cases                               1.000000
# abetment_to_suicide_women                                 0.831479
# attempt_to_murder_women                                   0.827388
# insult_outraging_modesty_other                            0.828222
# sexual_harassment_workplace                               0.830619
# dowry_harassment                                          0.829705
# marital_rape_reports                                      0.830117
# total_cases                                               0.911251
#
#                                        abetment_to_suicide_women  \
# year                                                    0.095708
# rape                                                    0.833860
# attempt_to_rape                                         0.828310
# gang_rape                                               0.829156
# murder_with_rape                                        0.829079
# kidnapping_and_abduction                                0.791817
# dowry_deaths                                            0.832663
# dowry_prohibition_act                                   0.830102
# cruelty_by_husband_or_relatives_498A                    0.795403
# acid_attack                                             0.827028
# attempt_to_acid_attack                                  0.830988
# assault_on_women_modesty_354                            0.791145
# assault_intent_disrobe_354B                             0.828821
# voyeurism_354C                                          0.830951
# stalking_354D                                           0.827967
# insult_to_modesty_509                                   0.827043
# trafficking                                             0.829768
# procuration_of_minor_girls                              0.830189
# importation_of_girls                                    0.829843
# immoral_traffic_act                                     0.831561
# indecent_representation_of_women                        0.827736
# women_killed_in_honour_killing                          0.828015
# witch_hunting                                           0.834768
# cyber_crime_obscenity_against_women                     0.828906
# cyber_stalking_bullying_against_women                   0.836787
# child_marriage_prohibition_act                          0.828589
# pocso_rape                                              0.831704
# pocso_assault                                           0.831362
# pocso_harassment                                        0.832008
# pocso_unnatural_offences                                0.832774
# pocso_other                                             0.829717
# abduction_for_marriage                                  0.829703
# abduction_for_illicit_intercourse                       0.832106
# attempt_to_kidnap                                       0.829178
# domestic_violence_act_cases                             0.831479
# abetment_to_suicide_women                               1.000000
# attempt_to_murder_women                                 0.830242
# insult_outraging_modesty_other                          0.828398
# sexual_harassment_workplace                             0.828617
# dowry_harassment                                        0.834195
# marital_rape_reports                                    0.832077
# total_cases                                             0.912195
#
#                                        attempt_to_murder_women  \
# year                                                  0.089935
# rape                                                  0.833680
# attempt_to_rape                                       0.831410
# gang_rape                                             0.835480
# murder_with_rape                                      0.829606
# kidnapping_and_abduction                              0.795503
# dowry_deaths                                          0.833712
# dowry_prohibition_act                                 0.829479
# cruelty_by_husband_or_relatives_498A                  0.797165
# acid_attack                                           0.825506
# attempt_to_acid_attack                                0.831888
# assault_on_women_modesty_354                          0.790063
# assault_intent_disrobe_354B                           0.831022
# voyeurism_354C                                        0.833657
# stalking_354D                                         0.829167
# insult_to_modesty_509                                 0.833515
# trafficking                                           0.830373
# procuration_of_minor_girls                            0.832919
# importation_of_girls                                  0.826739
# immoral_traffic_act                                   0.834161
# indecent_representation_of_women                      0.832529
# women_killed_in_honour_killing                        0.828952
# witch_hunting                                         0.835257
# cyber_crime_obscenity_against_women                   0.829892
# cyber_stalking_bullying_against_women                 0.832477
# child_marriage_prohibition_act                        0.833993
# pocso_rape                                            0.834286
# pocso_assault                                         0.834278
# pocso_harassment                                      0.832431
# pocso_unnatural_offences                              0.826977
# pocso_other                                           0.832663
# abduction_for_marriage                                0.827949
# abduction_for_illicit_intercourse                     0.832482
# attempt_to_kidnap                                     0.831256
# domestic_violence_act_cases                           0.827388
# abetment_to_suicide_women                             0.830242
# attempt_to_murder_women                               1.000000
# insult_outraging_modesty_other                        0.829016
# sexual_harassment_workplace                           0.829615
# dowry_harassment                                      0.832614
# marital_rape_reports                                  0.832042
# total_cases                                           0.912959
#
#                                        insult_outraging_modesty_other  \
# year                                                         0.102501
# rape                                                         0.832744
# attempt_to_rape                                              0.828100
# gang_rape                                                    0.830304
# murder_with_rape                                             0.829215
# kidnapping_and_abduction                                     0.790211
# dowry_deaths                                                 0.830214
# dowry_prohibition_act                                        0.827110
# cruelty_by_husband_or_relatives_498A                         0.792299
# acid_attack                                                  0.826948
# attempt_to_acid_attack                                       0.831842
# assault_on_women_modesty_354                                 0.793708
# assault_intent_disrobe_354B                                  0.832223
# voyeurism_354C                                               0.829936
# stalking_354D                                                0.829219
# insult_to_modesty_509                                        0.829428
# trafficking                                                  0.829384
# procuration_of_minor_girls                                   0.830709
# importation_of_girls                                         0.828374
# immoral_traffic_act                                          0.830348
# indecent_representation_of_women                             0.830185
# women_killed_in_honour_killing                               0.828634
# witch_hunting                                                0.833667
# cyber_crime_obscenity_against_women                          0.830070
# cyber_stalking_bullying_against_women                        0.833291
# child_marriage_prohibition_act                               0.833726
# pocso_rape                                                   0.827562
# pocso_assault                                                0.833047
# pocso_harassment                                             0.833754
# pocso_unnatural_offences                                     0.830496
# pocso_other                                                  0.830119
# abduction_for_marriage                                       0.826037
# abduction_for_illicit_intercourse                            0.823461
# attempt_to_kidnap                                            0.825223
# domestic_violence_act_cases                                  0.828222
# abetment_to_suicide_women                                    0.828398
# attempt_to_murder_women                                      0.829016
# insult_outraging_modesty_other                               1.000000
# sexual_harassment_workplace                                  0.830747
# dowry_harassment                                             0.829229
# marital_rape_reports                                         0.829713
# total_cases                                                  0.910818
#
#                                        sexual_harassment_workplace  \
# year                                                      0.090805
# rape                                                      0.832418
# attempt_to_rape                                           0.830952
# gang_rape                                                 0.831900
# murder_with_rape                                          0.829466
# kidnapping_and_abduction                                  0.788178
# dowry_deaths                                              0.828178
# dowry_prohibition_act                                     0.831314
# cruelty_by_husband_or_relatives_498A                      0.793854
# acid_attack                                               0.829173
# attempt_to_acid_attack                                    0.833287
# assault_on_women_modesty_354                              0.794488
# assault_intent_disrobe_354B                               0.830487
# voyeurism_354C                                            0.832804
# stalking_354D                                             0.826649
# insult_to_modesty_509                                     0.831697
# trafficking                                               0.829428
# procuration_of_minor_girls                                0.828811
# importation_of_girls                                      0.829257
# immoral_traffic_act                                       0.829938
# indecent_representation_of_women                          0.828405
# women_killed_in_honour_killing                            0.831737
# witch_hunting                                             0.835167
# cyber_crime_obscenity_against_women                       0.826373
# cyber_stalking_bullying_against_women                     0.833626
# child_marriage_prohibition_act                            0.835475
# pocso_rape                                                0.831362
# pocso_assault                                             0.833379
# pocso_harassment                                          0.828742
# pocso_unnatural_offences                                  0.828716
# pocso_other                                               0.830222
# abduction_for_marriage                                    0.828857
# abduction_for_illicit_intercourse                         0.832057
# attempt_to_kidnap                                         0.831668
# domestic_violence_act_cases                               0.830619
# abetment_to_suicide_women                                 0.828617
# attempt_to_murder_women                                   0.829615
# insult_outraging_modesty_other                            0.830747
# sexual_harassment_workplace                               1.000000
# dowry_harassment                                          0.830506
# marital_rape_reports                                      0.831287
# total_cases                                               0.911983
#
#                                        dowry_harassment  marital_rape_reports  \
# year                                           0.092736              0.093429
# rape                                           0.834665              0.832676
# attempt_to_rape                                0.831171              0.825845
# gang_rape                                      0.828729              0.836286
# murder_with_rape                               0.831096              0.830816
# kidnapping_and_abduction                       0.791226              0.790315
# dowry_deaths                                   0.833408              0.832886
# dowry_prohibition_act                          0.829080              0.828062
# cruelty_by_husband_or_relatives_498A           0.797284              0.791693
# acid_attack                                    0.826012              0.827215
# attempt_to_acid_attack                         0.829731              0.831596
# assault_on_women_modesty_354                   0.798314              0.791490
# assault_intent_disrobe_354B                    0.832505              0.828082
# voyeurism_354C                                 0.831236              0.831342
# stalking_354D                                  0.831204              0.828092
# insult_to_modesty_509                          0.835224              0.829015
# trafficking                                    0.830723              0.827049
# procuration_of_minor_girls                     0.832659              0.834414
# importation_of_girls                           0.830681              0.832422
# immoral_traffic_act                            0.831297              0.834896
# indecent_representation_of_women               0.828554              0.829145
# women_killed_in_honour_killing                 0.827746              0.831447
# witch_hunting                                  0.832158              0.833580
# cyber_crime_obscenity_against_women            0.826521              0.826244
# cyber_stalking_bullying_against_women          0.833613              0.832123
# child_marriage_prohibition_act                 0.832745              0.830775
# pocso_rape                                     0.830583              0.828097
# pocso_assault                                  0.834630              0.834845
# pocso_harassment                               0.833698              0.831242
# pocso_unnatural_offences                       0.831771              0.830853
# pocso_other                                    0.830039              0.832068
# abduction_for_marriage                         0.825730              0.828075
# abduction_for_illicit_intercourse              0.832450              0.827284
# attempt_to_kidnap                              0.830229              0.830125
# domestic_violence_act_cases                    0.829705              0.830117
# abetment_to_suicide_women                      0.834195              0.832077
# attempt_to_murder_women                        0.832614              0.832042
# insult_outraging_modesty_other                 0.829229              0.829713
# sexual_harassment_workplace                    0.830506              0.831287
# dowry_harassment                               1.000000              0.829647
# marital_rape_reports                           0.829647              1.000000
# total_cases                                    0.912669              0.912384
#
#                                        total_cases
# year                                      0.106338
# rape                                      0.915718
# attempt_to_rape                           0.910316
# gang_rape                                 0.912711
# murder_with_rape                          0.912118
# kidnapping_and_abduction                  0.870920
# dowry_deaths                              0.913032
# dowry_prohibition_act                     0.910956
# cruelty_by_husband_or_relatives_498A      0.873251
# acid_attack                               0.910116
# attempt_to_acid_attack                    0.912431
# assault_on_women_modesty_354              0.872705
# assault_intent_disrobe_354B               0.911919
# voyeurism_354C                            0.912383
# stalking_354D                             0.910865
# insult_to_modesty_509                     0.911885
# trafficking                               0.911140
# procuration_of_minor_girls                0.913507
# importation_of_girls                      0.912009
# immoral_traffic_act                       0.914786
# indecent_representation_of_women          0.911649
# women_killed_in_honour_killing            0.912201
# witch_hunting                             0.914486
# cyber_crime_obscenity_against_women       0.910748
# cyber_stalking_bullying_against_women     0.915850
# child_marriage_prohibition_act            0.913745
# pocso_rape                                0.912533
# pocso_assault                             0.915524
# pocso_harassment                          0.912851
# pocso_unnatural_offences                  0.911699
# pocso_other                               0.912260
# abduction_for_marriage                    0.909163
# abduction_for_illicit_intercourse         0.912282
# attempt_to_kidnap                         0.912938
# domestic_violence_act_cases               0.911251
# abetment_to_suicide_women                 0.912195
# attempt_to_murder_women                   0.912959
# insult_outraging_modesty_other            0.910818
# sexual_harassment_workplace               0.911983
# dowry_harassment                          0.912669
# marital_rape_reports                      0.912384
# total_cases                               1.000000
#
# [42 rows x 42 columns]

# %% [markdown]
# ## Relationship Between Rape Cases and Murder with Rape Cases (2001-2020)
#
# This scatter plot visualizes the relationship between **Rape cases** and **Murder with Rape cases** across different districts for each year from 2001 to 2020.
#
# ### 🔹 What does the code do?
# - It creates a **scatterplot** using the `numeric_df` DataFrame.
# - The **x-axis** represents the number of **rape cases**.
# - The **y-axis** represents the number of **murder with rape cases**.
# - The **color** of each point on the scatter plot indicates the **year**, using the 'Set1' color palette to differentiate between years.
#
# ### 🔹 Why this visualization?
# - **Visualize Correlation:** It helps to visually assess if there is a correlation between the number of rape cases and the number of murder with rape cases. A positive correlation would suggest that as rape cases increase, murder with rape cases also tend to increase.
# - **Identify Trends Over Time:** By using 'year' as the hue, we can see if the relationship between these two crime types changes over the years. Different colored clusters or patterns could indicate shifts in the nature of these crimes.
# - **Detect Outliers:** The scatter plot can reveal outliers, which are districts with unusually high or low numbers of either crime relative to the other.
# - **Understand Distribution:** It provides a visual representation of how these two crime types are distributed across the data points (districts and years).
#
# ### 🔹 Key Insights
# - The clustering or spread of the points can indicate the strength and direction of the relationship.
# - The colors can highlight if certain years have a different distribution of cases compared to others.
# - This plot is useful for understanding if these two severe crimes are linked and how this linkage might evolve over time.

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=numeric_df,x='rape',y='murder_with_rape',hue='year',palette='Set1')
plt.title("Describing Correlation with Scatterplot")
# Out:
# Text(0.5, 1.0, 'Describing Correlation with Scatterplot')
